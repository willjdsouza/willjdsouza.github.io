# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %%
set_values_1 = np.random.random_integers(1, 10000, 10000).reshape(-1,1)
set_values_2 = np.random.random_integers(1, 10000, 10000).reshape(-1,1)
y_values = np.random.random_integers(0, 1, 10000).reshape(-1,1)

# %%
x_values = np.append(set_values_1, set_values_2, axis = 1)

# %%
rfc = KNeighborsClassifier().fit(x_values, y_values)
results = rfc.predict(x_values)

# %%
from sklearn.model_selection import learning_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# Create CV training and test scores for various training set sizes
train_sizes, train_scores, test_scores = learning_curve(RandomForestClassifier(n_estimators = 10000), 
                                                        x_values, 
                                                        y_values,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring = 'neg_log_loss',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-154-9e04ab63d5c4> in <module>
#      14                                                         n_jobs=-1,
#      15                                                         # 50 different sizes of the training set
# ---> 16                                                         train_sizes=np.linspace(0.01, 1.0, 50))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score)
#    1244             parameters=None, fit_params=None, return_train_score=True,
#    1245             error_score=error_score)
# -> 1246             for train, test in train_test_proportions)
#    1247         out = np.array(out)
# ...

# %%
# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
test = list(train_sizes)
test2 = list(train_mean)
test3 = list(test_mean)
std = list(test_std)

# %%
fig, ax = plt.subplots()
line1, = ax.plot(test, test2, color = "r")
line2, = ax.plot(test, test3, color = "g")
# plt.fill_between(test, test2 - train_std, train_mean + train_std, color="#DDDDDD")
# plt.fill_between(test, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

def update(num, x, y, z, line1, line2):
    line1.set_data(x[:num], y[:num])
    line2.set_data(x[:num], z[:num])
    line.axes.axis([0, 1000, 0, 1])
    return [line1, line2]

ani = FuncAnimation(fig, update, len(test), fargs=[test, test2, test3, line1, line2],
                              interval=75, blit=True)


ani.save('test.gif')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-b17091556fce> in <module>
#      13     return [line1, line2]
#      14
# ---> 15 ani = FuncAnimation(fig, update, len(test), fargs=[test, test2, test3, line1, line2],
#      16                               interval=75, blit=True)
#      17
#
# NameError: name 'FuncAnimation' is not defined

# %%
len(test2)
# Out:
# 51
